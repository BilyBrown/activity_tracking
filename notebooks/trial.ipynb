# %%
import pandas as pd

# %%
trial_df = pd.read_csv("/home/bily/python/activity_tracker/data/Recovery workout log - barbell weights.csv")

# %%
trial_df.head()
# Out:
#       date              exercise  reps  set  mass (lbs)  mass (kgs)  rest  \
# 0  25.8.15    calf raise machine    10    3           0         0.0  60.0
# 1  25.8.15  heel raise squat bar    10    3           0         0.0  60.0
# 2  25.8.15       1 leg extension    10    3          45        20.0  60.0
# 3  25.8.15            1 leg curl    10    3          30        14.0  60.0
# 4  25.8.22    calf raise machine    10    3           0         0.0  60.0
#
#             notes to failure?
# 0  60/40 2 legged         yes
# 1             NaN         yes
# 2             NaN         yes
# 3             NaN         yes
# 4  70/30 2 legged         yes

# %%
trial_df.loc[trial_df['exercise'].str.contains("dead"), 'mass (lbs)'].max()
# Out:
# 253

# %%
index = trial_df[trial_df['date'].str.count('\.') == 1].index
index
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_11181/4103893233.py:1: SyntaxWarning: invalid escape sequence '\.'
#   index = trial_df[trial_df['column_name'].str.count('\.') == 1].index
# Index([167, 170, 171, 172], dtype='int64')

# %%
a = "24.03.24"
print(a.replace(".", ''))
# Out:
# 240324

# %%
def fix_date(value):
    fresh_start = value.replace(".", "").strip().replace(" ", "")
    if len(fresh_start) == 6:
        new_value = fresh_start[0:2] + "." + fresh_start[2:4] + "." + fresh_start[4:6]
    elif len(fresh_start) == 5:
        if fresh_start[0:3] == "258":
            new_value = fresh_start[0:2] + ".0" + fresh_start[2:3] + "." + fresh_start[3:5]
    else:
        new_value = "bugger"
    return new_value

trial_df['column_name'] = trial_df['date'].apply(fix_date)

# %%
trial_df[trial_df['column_name'] == 'bugger']
# Out:
# Empty DataFrame
# Columns: [date, exercise, reps, set, mass (lbs), mass (kgs), rest, notes, to failure?, fakedate, column_name]
# Index: []

# %%
trial_df.head()
# Out:
#       date              exercise  reps  set  mass (lbs)  mass (kgs)  rest  \
# 0  25.8.15    calf raise machine    10    3           0         0.0  60.0
# 1  25.8.15  heel raise squat bar    10    3           0         0.0  60.0
# 2  25.8.15       1 leg extension    10    3          45        20.0  60.0
# 3  25.8.15            1 leg curl    10    3          30        14.0  60.0
# 4  25.8.22    calf raise machine    10    3           0         0.0  60.0
#
#             notes to failure?     fakedate column_name
# 0  60/40 2 legged         yes  [25, 8, 15]    25.08.15
# 1             NaN         yes  [25, 8, 15]    25.08.15
# 2             NaN         yes  [25, 8, 15]    25.08.15
# 3             NaN         yes  [25, 8, 15]    25.08.15
# 4  70/30 2 legged         yes  [25, 8, 22]    25.08.22

# %%
trial_df['date'] = pd.to_datetime(trial_df['column_name'], format='%y.%m.%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 trial_df['date'] = pd.to_datetime(trial_df['column_name'], format='%y.%m.%d')
#
# File ~/anaconda3/envs/aws_trial/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~/anaconda3/envs/aws_trial/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...
